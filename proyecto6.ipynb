# %%
import pandas as pd

# %%
import numpy as np
import plotly
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
datos = pd.read_excel("/content/2020 colombia.xlsx")

# %%
datos
# Out:
#                   Exporters  Imported value in 2001  Imported value in 2002  \
# 0  United States of America                 4442775                 4051198
# 1                     China                  475405                  532847
# 2                    Mexico                  596168                  677990
# 3                    Brazil                  582060                  642840
# 4                   Germany                  560090                  508304
#
#    Imported value in 2003  Imported value in 2004  Imported value in 2005  \
# 0                 4112710                 4806760                 6033241
# 1                  688673                 1244730                 1616821
# 2                  744375                  935642                 1757068
# 3                  769003                 1352172                 1383387
# 4                  611672                  686601                  773661
#
# ...

# %%
datos=datos.set_index("Exporters")

# %%
datos
# Out:
#                           Imported value in 2001  Imported value in 2002  \
# Exporters
# United States of America                 4442775                 4051198
# China                                     475405                  532847
# Mexico                                    596168                  677990
# Brazil                                    582060                  642840
# Germany                                   560090                  508304
#
#                           Imported value in 2003  Imported value in 2004  \
# Exporters
# United States of America                 4112710                 4806760
# China                                     688673                 1244730
# Mexico                                    744375                  935642
# Brazil                                    769003                 1352172
# Germany                                   611672                  686601
#
# ...

# %%
datos.T.plot(figsize=(14,8))

# %%
datos = datos.rename(columns={"Imported value in 2001":2001})
datos = datos.rename(columns={"Imported value in 2002":2002})
datos = datos.rename(columns={"Imported value in 2003":2003})
datos = datos.rename(columns={"Imported value in 2004":2004})
datos = datos.rename(columns={"Imported value in 2005":2005})
datos = datos.rename(columns={"Imported value in 2006":2006})
datos = datos.rename(columns={"Imported value in 2007":2007})
datos = datos.rename(columns={"Imported value in 2008":2008})
datos = datos.rename(columns={"Imported value in 2009":2009})
datos = datos.rename(columns={"Imported value in 2010":2010})
datos = datos.rename(columns={"Imported value in 2011":2011})
datos = datos.rename(columns={"Imported value in 2012":2012})
datos = datos.rename(columns={"Imported value in 2013":2013})
datos = datos.rename(columns={"Imported value in 2014":2014})
datos = datos.rename(columns={"Imported value in 2015":2015})
datos = datos.rename(columns={"Imported value in 2016":2016})
datos = datos.rename(columns={"Imported value in 2017":2017})
datos = datos.rename(columns={"Imported value in 2018":2018})
datos = datos.rename(columns={"Imported value in 2019":2019})
datos = datos.rename(columns={"Imported value in 2020":2020})

# %%
datos
# Out:
#                              2001     2002     2003     2004     2005  \
# Exporters
# United States of America  4442775  4051198  4112710  4806760  6033241
# China                      475405   532847   688673  1244730  1616821
# Mexico                     596168   677990   744375   935642  1757068
# Brazil                     582060   642840   769003  1352172  1383387
# Germany                    560090   508304   611672   686601   773661
#
#                              2006     2007      2008     2009      2010  \
# Exporters
# United States of America  6960605  8631115  11583019  9505791  10531813
# China                     2219273  3326574   4548798  3715170   5477428
# Mexico                    2290571  3072565   3125980  2297888   3856674
# Brazil                    1884885  2393940   2328416  2146578   2369637
# Germany                    933215  1204874   1557401  1338394   1657634
#
#                               2011      2012      2013      2014      2015  \
# ...

# %%
datos.T.plot(figsize=(20,12))

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(datos, cmap='flare')
